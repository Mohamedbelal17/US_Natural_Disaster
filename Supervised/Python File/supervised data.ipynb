# %% [markdown]
# ![Screenshot%20%28363%29.png](attachment:Screenshot%20%28363%29.png)

# %% [markdown]
# | Column Name | Description |
# :------------|:----------
# |Timestamp | Timestamp|
# |    Age    |      Age |
# | Gender    | Gender |
# | Country | Country |
# | state |   If you live in the United States, which state or territory do you live in? |
# | self_employed |   Are you self-employed? |
# | family_history | Do you have a family history of mental illness? |
# | treatment | Have you sought treatment for a mental health condition? |
# | work_interfere | If you have a mental health condition, do you feel that it interferes with your work? |
# | no_employees | How many employees does your company or organization have? |
# | remote_work | Do you work remotely (outside of an office) at least 50% of the time? |
# | tech_company | Is your employer primarily a tech company/organization? |
# | benefits | Does your employer provide mental health benefits? |
# | care_options | Do you know the options for mental health care your employer provides? |
# | wellness_program | Has your employer ever discussed mental health as part of an employee wellness program? |
# | seek_help | Does your employer provide resources to learn more about mental health issues and how to seek help? |
# |anonymity|Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatmentresources?|
# | leave | How easy is it for you to take medical leave for a mental health condition? |
# |mentalhealthconsequence| Do you think that discussing a mental health issue with your employer would have negative consequences?|
# | physhealthconsequence | Do you think that discussing a physical health issue with your employer would have negative consequences? |
# | coworkers |   Would you be willing to discuss a mental health issue with your coworkers? |
# | supervisor |   Would you be willing to discuss a mental health issue with your direct supervisor(s)? |
# | mentalhealthinterview | Would you bring up a mental health issue with a potential employer in an interview? |
# | physhealthinterview |   Would you bring up a physical health issue with a potential employer in an interview? |
# |    mentalvsphysical    | Do you feel that your employer takes mental health as seriously as physical health? |
# |obs_consequence|Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace? |
# |    comments    |  Any additional notes or comments |

# %% [markdown]
# ## Importing important libraries

# %%
# %clear

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
import math
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ![Screenshot%20%28371%29.png](attachment:Screenshot%20%28371%29.png)

# %% [markdown]
# ## Reading our data using pandas package and quickly testing if we have the right data using the .head() method and choosing a pink background color to matchour notebook theme

# %%
data=pd.read_csv('C:\\Users\\sarah\\Desktop\\survey.csv')
data.head(10).style.applymap(lambda x : "background-color: #f5e9f2")
# Out:
# <style type="text/css">
# #T_e597c_row0_col0, #T_e597c_row0_col1, #T_e597c_row0_col2, #T_e597c_row0_col3, #T_e597c_row0_col4, #T_e597c_row0_col5, #T_e597c_row0_col6, #T_e597c_row0_col7, #T_e597c_row0_col8, #T_e597c_row0_col9, #T_e597c_row0_col10, #T_e597c_row0_col11, #T_e597c_row0_col12, #T_e597c_row0_col13, #T_e597c_row0_col14, #T_e597c_row0_col15, #T_e597c_row0_col16, #T_e597c_row0_col17, #T_e597c_row0_col18, #T_e597c_row0_col19, #T_e597c_row0_col20, #T_e597c_row0_col21, #T_e597c_row0_col22, #T_e597c_row0_col23, #T_e597c_row0_col24, #T_e597c_row0_col25, #T_e597c_row0_col26, #T_e597c_row1_col0, #T_e597c_row1_col1, #T_e597c_row1_col2, #T_e597c_row1_col3, #T_e597c_row1_col4, #T_e597c_row1_col5, #T_e597c_row1_col6, #T_e597c_row1_col7, #T_e597c_row1_col8, #T_e597c_row1_col9, #T_e597c_row1_col10, #T_e597c_row1_col11, #T_e597c_row1_col12, #T_e597c_row1_col13, #T_e597c_row1_col14, #T_e597c_row1_col15, #T_e597c_row1_col16, #T_e597c_row1_col17, #T_e597c_row1_col18, #T_e597c_row1_col19, #T_e597c_row1_col20, #T_e597c_row1_col21, #T_e597c_row1_col22, #T_e597c_row1_col23, #T_e597c_row1_col24, #T_e597c_row1_col25, #T_e597c_row1_col26, #T_e597c_row2_col0, #T_e597c_row2_col1, #T_e597c_row2_col2, #T_e597c_row2_col3, #T_e597c_row2_col4, #T_e597c_row2_col5, #T_e597c_row2_col6, #T_e597c_row2_col7, #T_e597c_row2_col8, #T_e597c_row2_col9, #T_e597c_row2_col10, #T_e597c_row2_col11, #T_e597c_row2_col12, #T_e597c_row2_col13, #T_e597c_row2_col14, #T_e597c_row2_col15, #T_e597c_row2_col16, #T_e597c_row2_col17, #T_e597c_row2_col18, #T_e597c_row2_col19, #T_e597c_row2_col20, #T_e597c_row2_col21, #T_e597c_row2_col22, #T_e597c_row2_col23, #T_e597c_row2_col24, #T_e597c_row2_col25, #T_e597c_row2_col26, #T_e597c_row3_col0, #T_e597c_row3_col1, #T_e597c_row3_col2, #T_e597c_row3_col3, #T_e597c_row3_col4, #T_e597c_row3_col5, #T_e597c_row3_col6, #T_e597c_row3_col7, #T_e597c_row3_col8, #T_e597c_row3_col9, #T_e597c_row3_col10, #T_e597c_row3_col11, #T_e597c_row3_col12, #T_e597c_row3_col13, #T_e597c_row3_col14, #T_e597c_row3_col15, #T_e597c_row3_col16, #T_e597c_row3_col17, #T_e597c_row3_col18, #T_e597c_row3_col19, #T_e597c_row3_col20, #T_e597c_row3_col21, #T_e597c_row3_col22, #T_e597c_row3_col23, #T_e597c_row3_col24, #T_e597c_row3_col25, #T_e597c_row3_col26, #T_e597c_row4_col0, #T_e597c_row4_col1, #T_e597c_row4_col2, #T_e597c_row4_col3, #T_e597c_row4_col4, #T_e597c_row4_col5, #T_e597c_row4_col6, #T_e597c_row4_col7, #T_e597c_row4_col8, #T_e597c_row4_col9, #T_e597c_row4_col10, #T_e597c_row4_col11, #T_e597c_row4_col12, #T_e597c_row4_col13, #T_e597c_row4_col14, #T_e597c_row4_col15, #T_e597c_row4_col16, #T_e597c_row4_col17, #T_e597c_row4_col18, #T_e597c_row4_col19, #T_e597c_row4_col20, #T_e597c_row4_col21, #T_e597c_row4_col22, #T_e597c_row4_col23, #T_e597c_row4_col24, #T_e597c_row4_col25, #T_e597c_row4_col26, #T_e597c_row5_col0, #T_e597c_row5_col1, #T_e597c_row5_col2, #T_e597c_row5_col3, #T_e597c_row5_col4, #T_e597c_row5_col5, #T_e597c_row5_col6, #T_e597c_row5_col7, #T_e597c_row5_col8, #T_e597c_row5_col9, #T_e597c_row5_col10, #T_e597c_row5_col11, #T_e597c_row5_col12, #T_e597c_row5_col13, #T_e597c_row5_col14, #T_e597c_row5_col15, #T_e597c_row5_col16, #T_e597c_row5_col17, #T_e597c_row5_col18, #T_e597c_row5_col19, #T_e597c_row5_col20, #T_e597c_row5_col21, #T_e597c_row5_col22, #T_e597c_row5_col23, #T_e597c_row5_col24, #T_e597c_row5_col25, #T_e597c_row5_col26, #T_e597c_row6_col0, #T_e597c_row6_col1, #T_e597c_row6_col2, #T_e597c_row6_col3, #T_e597c_row6_col4, #T_e597c_row6_col5, #T_e597c_row6_col6, #T_e597c_row6_col7, #T_e597c_row6_col8, #T_e597c_row6_col9, #T_e597c_row6_col10, #T_e597c_row6_col11, #T_e597c_row6_col12, #T_e597c_row6_col13, #T_e597c_row6_col14, #T_e597c_row6_col15, #T_e597c_row6_col16, #T_e597c_row6_col17, #T_e597c_row6_col18, #T_e597c_row6_col19, #T_e597c_row6_col20, #T_e597c_row6_col21, #T_e597c_row6_col22, #T_e597c_row6_col23, #T_e597c_row6_col24, #T_e597c_row6_col25, #T_e597c_row6_col26, #T_e597c_row7_col0, #T_e597c_row7_col1, #T_e597c_row7_col2, #T_e597c_row7_col3, #T_e597c_row7_col4, # ...
#   background-color: #f5e9f2;
# }
# </style>
# <table id="T_e597c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e597c_level0_col0" class="col_heading level0 col0" >Timestamp</th>
#       <th id="T_e597c_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_e597c_level0_col2" class="col_heading level0 col2" >Gender</th>
#       <th id="T_e597c_level0_col3" class="col_heading level0 col3" >Country</th>
#       <th id="T_e597c_level0_col4" class="col_heading level0 col4" >state</th>
#       <th id="T_e597c_level0_col5" class="col_heading level0 col5" >self_employed</th>
#       <th id="T_e597c_level0_col6" class="col_heading level0 col6" >family_history</th>
#       <th id="T_e597c_level0_col7" class="col_heading level0 col7" >treatment</th>
#       <th id="T_e597c_level0_col8" class="col_heading level0 col8" >work_interfere</th>
#       <th id="T_e597c_level0_col9" class="col_heading level0 col9" >no_employees</th>
#       <th id="T_e597c_level0_col10" class="col_heading level0 col10" >remote_work</th>
#       <th id="T_e597c_level0_col11" class="col_heading level0 col11" >tech_company</th>
#       <th id="T_e597c_level0_col12" class="col_heading level0 col12" >benefits</th>
#       <th id="T_e597c_level0_col13" class="col_heading level0 col13" >care_options</th>
#       <th id="T_e597c_level0_col14" class="col_heading level0 col14" >wellness_program</th>
#       <th id="T_e597c_level0_col15" class="col_heading level0 col15" >seek_help</th>
#       <th id="T_e597c_level0_col16" class="col_heading level0 col16" >anonymity</th>
#       <th id="T_e597c_level0_col17" class="col_heading level0 col17" >leave</th>
#       <th id="T_e597c_level0_col18" class="col_heading level0 col18" >mental_health_consequence</th>
#       <th id="T_e597c_level0_col19" class="col_heading level0 col19" >phys_health_consequence</th>
#       <th id="T_e597c_level0_col20" class="col_heading level0 col20" >coworkers</th>
#       <th id="T_e597c_level0_col21" class="col_heading level0 col21" >supervisor</th>
#       <th id="T_e597c_level0_col22" class="col_heading level0 col22" >mental_health_interview</th>
#       <th id="T_e597c_level0_col23" class="col_heading level0 col23" >phys_health_interview</th>
#       <th id="T_e597c_level0_col24" class="col_heading level0 col24" >mental_vs_physical</th>
#       <th id="T_e597c_level0_col25" class="col_heading level0 col25" >obs_consequence</th>
#       <

# %% [markdown]
# # part 1

# %% [markdown]
# ![Screenshot%20%28386%29.png](attachment:Screenshot%20%28386%29.png)

# %% [markdown]
# ## Doing some EDA ( Exploratory Data Analysis ) to get an over view of our data

# %%
print('\033[1m' + 'Shape of the data (rows, columns):' + '\033[0m')
print(data.shape)
# Out:
# Shape of the data (rows, columns):
# (1259, 27)

# %% [markdown]
# ## Calculating every unique value in each column

# %%
for col in data.columns:
    print('\033[1m' + 'Unique values in {} :'.format(col) + '\033[0m',len(data[col].unique()))
# Out:
# Unique values in Timestamp : 1246
# Unique values in Age : 53
# Unique values in Gender : 49
# Unique values in Country : 48
# Unique values in state : 46
# Unique values in self_employed : 3
# Unique values in family_history : 2
# Unique values in treatment : 2
# Unique values in work_interfere : 5
# Unique values in no_employees : 6
# Unique values in remote_work : 2
# Unique values in tech_company : 2
# Unique values in benefits : 3
# Unique values in care_options : 3
# Unique values in wellness_program : 3
# Unique values in seek_help : 3
# Unique values in anonymity : 3
# Unique values in leave : 5
# Unique values in mental_health_consequence : 3
# Unique values in phys_health_consequence : 3
# Unique values in coworkers : 3
# Unique values in supervisor : 3
# Unique values in mental_health_interview : 3
# Unique values in phys_health_interview : 3
# Unique values in mental_vs_physical : 3
# Unique values in obs_consequence : 2
# Unique values in comments : 161

# %% [markdown]
# ![Screenshot%20%28366%29.png](attachment:Screenshot%20%28366%29.png)

# %% [markdown]
# # Missing values

# %% [markdown]
# ### Calculating the percentage of the missing value in each column (sate, work_interfere, self_employed, comments) by creating a function called missing_values_table and creating a table with column for the missing value number and another column for the missing values percentage to help us decide what we should do to fill in these values

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        table = pd.concat([mis_val, mis_val_percent], axis=1)

        col_names = table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        col_names= col_names[col_names.iloc[:,1] != 0].sort_values('% of Total Values',
                                                                   ascending=False).round(1)
        
        print ("Dataframe has " + str(df.shape[1]) + " columns,"      
            "And there exist " + str(col_names.shape[0]) +
              " columns missing value(s)")
        
        return col_names
    
summary=missing_values_table(data)
summary
# Out:
# Dataframe has 27 columns,And there exist 4 columns missing value(s)
#                 Missing Values  % of Total Values
# comments                  1095               87.0
# state                      515               40.9
# work_interfere             264               21.0
# self_employed               18                1.4

# %% [markdown]
# ## Visualizing the missing Value using heatmap from seaborn library to easily detect them

# %% [markdown]
# ### Notice the amount of missing values in work_interfere, self_employed and comments that need to be handled

# %%
plt.figure(figsize=(10,5) , dpi=100)
sns.heatmap(data.isna(), cmap='tab20b', alpha = 0.3)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Imputing missing values

# %%
(len(data[data['self_employed']=='Yes'])/len(data),len(data[data['self_employed']=='No'])/len(data))
# Out:
# (0.11596505162827642, 0.8697378872120731)

# %%
data['self_employed'] = data['self_employed'].fillna(pd.Series(np.random.choice(['Yes', 'No'], p=[ 0.11764705882352941, 0.8823529411764706], size=len(data))))

data['work_interfere'] = data['work_interfere'].fillna('not suffering')

print('Total empty values in the Dataset :', data.isnull().sum().sum())
# Out:
# Total empty values in the Dataset : 1610

# %% [markdown]
# ## Checking on the duplicated values

# %%
print('\033[1m' + 'Number of duplicate values :' + '\033[0m')
print(data.duplicated().sum())
# Out:
# Number of duplicate values :
# 0

# %% [markdown]
# there's no duplicates in data

# %% [markdown]
# ![Screenshot%20%28388%29.png](attachment:Screenshot%20%28388%29.png)

# %% [markdown]
# # Irrelevant Attributes
# ### All of these three features will not be helpful in the modeling phase so we drop the columns

# %%
data = data.drop(columns=['state', 'Timestamp', 'comments'])
print('Columns after update :', len(data.columns))
# Out:
# Columns after update : 24

# %% [markdown]
# ![Screenshot%20%28390%29.png](attachment:Screenshot%20%28390%29.png)

# %% [markdown]
# # Removing Noise

# %% [markdown]
# ## Printing out the unique values of the ages to check if there is any wrong insertions of the age value

# %%
data['Age'].unique()
# Out:
# array([         37,          44,          32,          31,          33,
#                 35,          39,          42,          23,          29,
#                 36,          27,          46,          41,          34,
#                 30,          40,          38,          50,          24,
#                 18,          28,          26,          22,          19,
#                 25,          45,          21,         -29,          43,
#                 56,          60,          54,         329,          55,
#        99999999999,          48,          20,          57,          58,
#                 47,          62,          51,          65,          49,
#              -1726,           5,          53,          61,           8,
#                 11,          -1,          72], dtype=int64)

# %% [markdown]
# ## Taking only the age range 18 to 70 in consideration because values like (-1 and 999999) are undoubtedly wrong insertions

# %%
data['Age'].replace([data['Age'][data['Age'] < 18]], np.nan, inplace = True)
data['Age'].replace([data['Age'][data['Age'] > 72]], np.nan, inplace = True)

data['Age'].unique()
# Out:
# array([37., 44., 32., 31., 33., 35., 39., 42., 23., 29., 36., 27., 46.,
#        41., 34., 30., 40., 38., 50., 24., 18., 28., 26., 22., 19., 25.,
#        45., 21., nan, 43., 56., 60., 54., 55., 48., 20., 57., 58., 47.,
#        62., 51., 65., 49., 53., 61., 72.])

# %%
data['Age'].isnull().sum()
# Out:
# 8

# %% [markdown]
# ## Notice how the age data is skewed (an indecator we can use median to fill in missing values)

# %%
sns.distplot(data.Age,)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## we use the median to fill the 8 missing age values we found

# %%
data['Age'] = data['Age'].fillna(data['Age'].median())
data['Age']
# Out:
# 0       37.0
# 1       44.0
# 2       32.0
# 3       31.0
# 4       31.0
#         ...
# 1254    26.0
# 1255    32.0
# 1256    34.0
# 1257    46.0
# 1258    25.0
# Name: Age, Length: 1259, dtype: float64

# %% [markdown]
# ## Why use the median ?

# %% [markdown]
# ![Screenshot%20%28396%29.png](attachment:Screenshot%20%28396%29.png)

# %%
data['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Printing out summary statistics for the age after filling in the missing values

# %%
print('Summary statistics for the data :')
data.describe()
# Out:
# Summary statistics for the data :
#                Age
# count  1259.000000
# mean     32.069897
# std       7.265565
# min      18.000000
# 25%      27.000000
# 50%      31.000000
# 75%      36.000000
# max      72.000000

# %% [markdown]
# ## We use unique()  to see all the unique values in Gender and then group them into three categories  Female, Male and others

# %%
data.Gender.unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
data['Gender'].replace(['Male ', 'male', 'M', 'm', 'Male', 'Cis Male','Man', 'cis male', 'Mail', 'Male-ish', 'Male (CIS)',
                    'Cis Man', 'msle', 'Malr', 'Mal', 'maile', 'Make',], 'Male', inplace = True)

data['Gender'].replace(['Female ', 'female', 'F', 'f', 'Woman', 'Female','femail', 'Cis Female', 'cis-female/femme', 
                    'Femake', 'Female (cis)','woman',], 'Female', inplace = True)

data["Gender"].replace(['Female (trans)', 'queer/she/they', 'non-binary','fluid', 'queer', 'Androgyne', 'Trans-female', 'male leaning androgynous',
                      'Agender', 'A little about you', 'Nah', 'All','ostensibly male, unsure what that really means',
                      'Genderqueer', 'Enby', 'p', 'Neuter', 'something kinda male?','Guy (-ish) ^_^', 'Trans woman',], 'Queer', inplace = True)

# %% [markdown]
# ![Screenshot%20%28392%29.png](attachment:Screenshot%20%28392%29.png)

# %% [markdown]
# # Correlation Matrix
# ## we calculated the correlation value of the data then we plotted the results using seaborn’s heatmap to visualize the result ,No value was greater than 0.8 or less than -0.8 so we don't have any features with high correlation that needs to be handled

# %%
df = data.copy()
cols = df.columns
encoder = LabelEncoder()
for col in cols:
    encoder.fit(df[col])
    df[col] = encoder.transform(df[col])

plt.figure(figsize = (16, 10), dpi = 100)

corr = df.corr()

mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True


sns.heatmap(corr, mask = mask , cmap = 'Pastel1', annot = True , linewidths = 0.5 , fmt = ".2f" , alpha = 0.6)
# Out:
# <AxesSubplot:>

# %% [markdown]
# there's no high correlated attribute (-0.8,0.8)

# %% [markdown]
# ![Screenshot%20%28369%29.png](attachment:Screenshot%20%28369%29.png)

# %% [markdown]
# #  Discretization

# %% [markdown]
# ## We discretized Age to a discrete set of ages  [youth, adults, seniors ]

# %%
data['Age_cat']=pd.cut(data.Age,bins=[17,25,64,72],labels=['Youth','Adult','Senior'])
data['Age_cat'].value_counts()
# Out:
# Adult     1040
# Youth      217
# Senior       2
# Name: Age_cat, dtype: int64

# %%
data.head(10).style.applymap(lambda x : "background-color: #f5e9f2")
# Out:
# <style type="text/css">
# #T_8a2a4_row0_col0, #T_8a2a4_row0_col1, #T_8a2a4_row0_col2, #T_8a2a4_row0_col3, #T_8a2a4_row0_col4, #T_8a2a4_row0_col5, #T_8a2a4_row0_col6, #T_8a2a4_row0_col7, #T_8a2a4_row0_col8, #T_8a2a4_row0_col9, #T_8a2a4_row0_col10, #T_8a2a4_row0_col11, #T_8a2a4_row0_col12, #T_8a2a4_row0_col13, #T_8a2a4_row0_col14, #T_8a2a4_row0_col15, #T_8a2a4_row0_col16, #T_8a2a4_row0_col17, #T_8a2a4_row0_col18, #T_8a2a4_row0_col19, #T_8a2a4_row0_col20, #T_8a2a4_row0_col21, #T_8a2a4_row0_col22, #T_8a2a4_row0_col23, #T_8a2a4_row0_col24, #T_8a2a4_row1_col0, #T_8a2a4_row1_col1, #T_8a2a4_row1_col2, #T_8a2a4_row1_col3, #T_8a2a4_row1_col4, #T_8a2a4_row1_col5, #T_8a2a4_row1_col6, #T_8a2a4_row1_col7, #T_8a2a4_row1_col8, #T_8a2a4_row1_col9, #T_8a2a4_row1_col10, #T_8a2a4_row1_col11, #T_8a2a4_row1_col12, #T_8a2a4_row1_col13, #T_8a2a4_row1_col14, #T_8a2a4_row1_col15, #T_8a2a4_row1_col16, #T_8a2a4_row1_col17, #T_8a2a4_row1_col18, #T_8a2a4_row1_col19, #T_8a2a4_row1_col20, #T_8a2a4_row1_col21, #T_8a2a4_row1_col22, #T_8a2a4_row1_col23, #T_8a2a4_row1_col24, #T_8a2a4_row2_col0, #T_8a2a4_row2_col1, #T_8a2a4_row2_col2, #T_8a2a4_row2_col3, #T_8a2a4_row2_col4, #T_8a2a4_row2_col5, #T_8a2a4_row2_col6, #T_8a2a4_row2_col7, #T_8a2a4_row2_col8, #T_8a2a4_row2_col9, #T_8a2a4_row2_col10, #T_8a2a4_row2_col11, #T_8a2a4_row2_col12, #T_8a2a4_row2_col13, #T_8a2a4_row2_col14, #T_8a2a4_row2_col15, #T_8a2a4_row2_col16, #T_8a2a4_row2_col17, #T_8a2a4_row2_col18, #T_8a2a4_row2_col19, #T_8a2a4_row2_col20, #T_8a2a4_row2_col21, #T_8a2a4_row2_col22, #T_8a2a4_row2_col23, #T_8a2a4_row2_col24, #T_8a2a4_row3_col0, #T_8a2a4_row3_col1, #T_8a2a4_row3_col2, #T_8a2a4_row3_col3, #T_8a2a4_row3_col4, #T_8a2a4_row3_col5, #T_8a2a4_row3_col6, #T_8a2a4_row3_col7, #T_8a2a4_row3_col8, #T_8a2a4_row3_col9, #T_8a2a4_row3_col10, #T_8a2a4_row3_col11, #T_8a2a4_row3_col12, #T_8a2a4_row3_col13, #T_8a2a4_row3_col14, #T_8a2a4_row3_col15, #T_8a2a4_row3_col16, #T_8a2a4_row3_col17, #T_8a2a4_row3_col18, #T_8a2a4_row3_col19, #T_8a2a4_row3_col20, #T_8a2a4_row3_col21, #T_8a2a4_row3_col22, #T_8a2a4_row3_col23, #T_8a2a4_row3_col24, #T_8a2a4_row4_col0, #T_8a2a4_row4_col1, #T_8a2a4_row4_col2, #T_8a2a4_row4_col3, #T_8a2a4_row4_col4, #T_8a2a4_row4_col5, #T_8a2a4_row4_col6, #T_8a2a4_row4_col7, #T_8a2a4_row4_col8, #T_8a2a4_row4_col9, #T_8a2a4_row4_col10, #T_8a2a4_row4_col11, #T_8a2a4_row4_col12, #T_8a2a4_row4_col13, #T_8a2a4_row4_col14, #T_8a2a4_row4_col15, #T_8a2a4_row4_col16, #T_8a2a4_row4_col17, #T_8a2a4_row4_col18, #T_8a2a4_row4_col19, #T_8a2a4_row4_col20, #T_8a2a4_row4_col21, #T_8a2a4_row4_col22, #T_8a2a4_row4_col23, #T_8a2a4_row4_col24, #T_8a2a4_row5_col0, #T_8a2a4_row5_col1, #T_8a2a4_row5_col2, #T_8a2a4_row5_col3, #T_8a2a4_row5_col4, #T_8a2a4_row5_col5, #T_8a2a4_row5_col6, #T_8a2a4_row5_col7, #T_8a2a4_row5_col8, #T_8a2a4_row5_col9, #T_8a2a4_row5_col10, #T_8a2a4_row5_col11, #T_8a2a4_row5_col12, #T_8a2a4_row5_col13, #T_8a2a4_row5_col14, #T_8a2a4_row5_col15, #T_8a2a4_row5_col16, #T_8a2a4_row5_col17, #T_8a2a4_row5_col18, #T_8a2a4_row5_col19, #T_8a2a4_row5_col20, #T_8a2a4_row5_col21, #T_8a2a4_row5_col22, #T_8a2a4_row5_col23, #T_8a2a4_row5_col24, #T_8a2a4_row6_col0, #T_8a2a4_row6_col1, #T_8a2a4_row6_col2, #T_8a2a4_row6_col3, #T_8a2a4_row6_col4, #T_8a2a4_row6_col5, #T_8a2a4_row6_col6, #T_8a2a4_row6_col7, #T_8a2a4_row6_col8, #T_8a2a4_row6_col9, #T_8a2a4_row6_col10, #T_8a2a4_row6_col11, #T_8a2a4_row6_col12, #T_8a2a4_row6_col13, #T_8a2a4_row6_col14, #T_8a2a4_row6_col15, #T_8a2a4_row6_col16, #T_8a2a4_row6_col17, #T_8a2a4_row6_col18, #T_8a2a4_row6_col19, #T_8a2a4_row6_col20, #T_8a2a4_row6_col21, #T_8a2a4_row6_col22, #T_8a2a4_row6_col23, #T_8a2a4_row6_col24, #T_8a2a4_row7_col0, #T_8a2a4_row7_col1, #T_8a2a4_row7_col2, #T_8a2a4_row7_col3, #T_8a2a4_row7_col4, #T_8a2a4_row7_col5, #T_8a2a4_row7_col6, #T_8a2a4_row7_col7, #T_8a2a4_row7_col8, #T_8a2a4_row7_col9, #T_8a2a4_row7_col10, #T_8a2a4_row7_col11, #T_8a2a4_row7_col12, #T_8a2a4_row7_col13, #T_8a2a4_row7_col14, #T_8a2a4_row7_col15, #T_8a2a4_row7_col16, #T_8a2a4_row7_col17, #T_8a2a4_row7_col18, #T_8a2 ...
#   background-color: #f5e9f2;
# }
# </style>
# <table id="T_8a2a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a2a4_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_8a2a4_level0_col1" class="col_heading level0 col1" >Gender</th>
#       <th id="T_8a2a4_level0_col2" class="col_heading level0 col2" >Country</th>
#       <th id="T_8a2a4_level0_col3" class="col_heading level0 col3" >self_employed</th>
#       <th id="T_8a2a4_level0_col4" class="col_heading level0 col4" >family_history</th>
#       <th id="T_8a2a4_level0_col5" class="col_heading level0 col5" >treatment</th>
#       <th id="T_8a2a4_level0_col6" class="col_heading level0 col6" >work_interfere</th>
#       <th id="T_8a2a4_level0_col7" class="col_heading level0 col7" >no_employees</th>
#       <th id="T_8a2a4_level0_col8" class="col_heading level0 col8" >remote_work</th>
#       <th id="T_8a2a4_level0_col9" class="col_heading level0 col9" >tech_company</th>
#       <th id="T_8a2a4_level0_col10" class="col_heading level0 col10" >benefits</th>
#       <th id="T_8a2a4_level0_col11" class="col_heading level0 col11" >care_options</th>
#       <th id="T_8a2a4_level0_col12" class="col_heading level0 col12" >wellness_program</th>
#       <th id="T_8a2a4_level0_col13" class="col_heading level0 col13" >seek_help</th>
#       <th id="T_8a2a4_level0_col14" class="col_heading level0 col14" >anonymity</th>
#       <th id="T_8a2a4_level0_col15" class="col_heading level0 col15" >leave</th>
#       <th id="T_8a2a4_level0_col16" class="col_heading level0 col16" >mental_health_consequence</th>
#       <th id="T_8a2a4_level0_col17" class="col_heading level0 col17" >phys_health_consequence</th>
#       <th id="T_8a2a4_level0_col18" class="col_heading level0 col18" >coworkers</th>
#       <th id="T_8a2a4_level0_col19" class="col_heading level0 col19" >supervisor</th>
#       <th id="T_8a2a4_level0_col20" class="col_heading level0 col20" >mental_health_interview</th>
#       <th id="T_8a2a4_level0_col21" class="col_heading level0 col21" >phys_health_interview</th>
#       <th id="T_8a2a4_level0_col22" class="col_heading level0 col22" >mental_vs_physical</th>
#       <th id="T_8a2a4_level0_col23" class="col_heading level0 col23" >obs_consequence</th>
#       <th id="T_8a2a4_level0_col24" class="col_heading level0 col24" >Age_cat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a2a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a2a4_row0_col0" class="data row0 col0" >37.000000</td>
#       <td id="T_8a2a4_row0_col1" class="data row0 col1" >Female</td>
#       <td id="T_8a2a4_row0_col2" class="data row0 col2" >United States</td>
#       <td id="T_8a2a4_row0_col3" class="data row0 col3" >No</td>
#       <td id="T_8a2a4_row0_col4" class="data row0 col4" >No</td>
#       <td id="T_8a2a4_row0_col5" class="data row

# %%
x=data['Age_cat'].value_counts().index
print(x)
y=data['Age_cat'].value_counts().values.tolist()
print(y)
# Out:
# CategoricalIndex(['Adult', 'Youth', 'Senior'], categories=['Youth', 'Adult', 'Senior'], ordered=True, dtype='category')
# [1040, 217, 2]

# %%
plt.figure(figsize=(8,8))
pal = sns.color_palette("PuRd")
#explode needs a length to function so making a for loop makes it more dynamic
plt.pie(y, labels=x, colors=pal,autopct='%1.1f%%',
        explode=[0.03 for i in data['Age_cat'].value_counts().index])
plt.show()

# %% [markdown]
# ## Writing and saving the data after the preprocessing phase to a csv file and an Excel worksheet to analyse it using data analysis tools like Power BI or tableau (Run only one time)

# %%
#data.to_excel('Clean_survey_data.xlsx')
#data.to_csv('Clean_survey_data.csv')

# %% [markdown]
# ## After using power BI for visualization we continue preprocessing

# %%
#drop age column and work with age category 
data = data.drop(columns=['Age'])

# %%
data['Country'].unique()
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Bulgaria', 'France',
#        'Portugal', 'Netherlands', 'Switzerland', 'Poland', 'Australia',
#        'Germany', 'Russia', 'Mexico', 'Brazil', 'Slovenia', 'Costa Rica',
#        'Austria', 'Ireland', 'India', 'South Africa', 'Italy', 'Sweden',
#        'Colombia', 'Latvia', 'Romania', 'Belgium', 'New Zealand',
#        'Zimbabwe', 'Spain', 'Finland', 'Uruguay', 'Israel',
#        'Bosnia and Herzegovina', 'Hungary', 'Singapore', 'Japan',
#        'Nigeria', 'Croatia', 'Norway', 'Thailand', 'Denmark',
#        'Bahamas, The', 'Greece', 'Moldova', 'Georgia', 'China',
#        'Czech Republic', 'Philippines'], dtype=object)

# %%
#group  the countries in form of continent as we can
data['Country'].replace(['United States','Canada','Mexico','Bahamas, The','Costa Rica'], 'North America', inplace = True)
data['Country'].replace(['United Kingdom','Bulgaria','France','Portugal' , 'Netherlands','Switzerland','Poland','Germany',
                        'Italy','Sweden','Latvia','Romania','Belgium','Spain','Finland','Bosnia and Herzegovina','Hungary',
                        'Croatia','Norway','Denmark','Greece','Moldova','Georgia','Czech Republic','Ireland','Slovenia',
                        'Austria'], 'Europe', inplace = True)
data['Country'].replace(['Zimbabwe', 'Nigeria'], 'Africa', inplace = True)
data['Country'].replace(['Russia','Israel','Singapore','Japan','Thailand','China','Philippines','India'], 'Asia', inplace = True)
data['Country'].replace(['Brazil','Colombia','Uruguay'], 'South America', inplace = True)

# %%
data.head().style.applymap(lambda x : "background-color: #f5e9f2")
# Out:
# <style type="text/css">
# #T_cfaf1_row0_col0, #T_cfaf1_row0_col1, #T_cfaf1_row0_col2, #T_cfaf1_row0_col3, #T_cfaf1_row0_col4, #T_cfaf1_row0_col5, #T_cfaf1_row0_col6, #T_cfaf1_row0_col7, #T_cfaf1_row0_col8, #T_cfaf1_row0_col9, #T_cfaf1_row0_col10, #T_cfaf1_row0_col11, #T_cfaf1_row0_col12, #T_cfaf1_row0_col13, #T_cfaf1_row0_col14, #T_cfaf1_row0_col15, #T_cfaf1_row0_col16, #T_cfaf1_row0_col17, #T_cfaf1_row0_col18, #T_cfaf1_row0_col19, #T_cfaf1_row0_col20, #T_cfaf1_row0_col21, #T_cfaf1_row0_col22, #T_cfaf1_row0_col23, #T_cfaf1_row1_col0, #T_cfaf1_row1_col1, #T_cfaf1_row1_col2, #T_cfaf1_row1_col3, #T_cfaf1_row1_col4, #T_cfaf1_row1_col5, #T_cfaf1_row1_col6, #T_cfaf1_row1_col7, #T_cfaf1_row1_col8, #T_cfaf1_row1_col9, #T_cfaf1_row1_col10, #T_cfaf1_row1_col11, #T_cfaf1_row1_col12, #T_cfaf1_row1_col13, #T_cfaf1_row1_col14, #T_cfaf1_row1_col15, #T_cfaf1_row1_col16, #T_cfaf1_row1_col17, #T_cfaf1_row1_col18, #T_cfaf1_row1_col19, #T_cfaf1_row1_col20, #T_cfaf1_row1_col21, #T_cfaf1_row1_col22, #T_cfaf1_row1_col23, #T_cfaf1_row2_col0, #T_cfaf1_row2_col1, #T_cfaf1_row2_col2, #T_cfaf1_row2_col3, #T_cfaf1_row2_col4, #T_cfaf1_row2_col5, #T_cfaf1_row2_col6, #T_cfaf1_row2_col7, #T_cfaf1_row2_col8, #T_cfaf1_row2_col9, #T_cfaf1_row2_col10, #T_cfaf1_row2_col11, #T_cfaf1_row2_col12, #T_cfaf1_row2_col13, #T_cfaf1_row2_col14, #T_cfaf1_row2_col15, #T_cfaf1_row2_col16, #T_cfaf1_row2_col17, #T_cfaf1_row2_col18, #T_cfaf1_row2_col19, #T_cfaf1_row2_col20, #T_cfaf1_row2_col21, #T_cfaf1_row2_col22, #T_cfaf1_row2_col23, #T_cfaf1_row3_col0, #T_cfaf1_row3_col1, #T_cfaf1_row3_col2, #T_cfaf1_row3_col3, #T_cfaf1_row3_col4, #T_cfaf1_row3_col5, #T_cfaf1_row3_col6, #T_cfaf1_row3_col7, #T_cfaf1_row3_col8, #T_cfaf1_row3_col9, #T_cfaf1_row3_col10, #T_cfaf1_row3_col11, #T_cfaf1_row3_col12, #T_cfaf1_row3_col13, #T_cfaf1_row3_col14, #T_cfaf1_row3_col15, #T_cfaf1_row3_col16, #T_cfaf1_row3_col17, #T_cfaf1_row3_col18, #T_cfaf1_row3_col19, #T_cfaf1_row3_col20, #T_cfaf1_row3_col21, #T_cfaf1_row3_col22, #T_cfaf1_row3_col23, #T_cfaf1_row4_col0, #T_cfaf1_row4_col1, #T_cfaf1_row4_col2, #T_cfaf1_row4_col3, #T_cfaf1_row4_col4, #T_cfaf1_row4_col5, #T_cfaf1_row4_col6, #T_cfaf1_row4_col7, #T_cfaf1_row4_col8, #T_cfaf1_row4_col9, #T_cfaf1_row4_col10, #T_cfaf1_row4_col11, #T_cfaf1_row4_col12, #T_cfaf1_row4_col13, #T_cfaf1_row4_col14, #T_cfaf1_row4_col15, #T_cfaf1_row4_col16, #T_cfaf1_row4_col17, #T_cfaf1_row4_col18, #T_cfaf1_row4_col19, #T_cfaf1_row4_col20, #T_cfaf1_row4_col21, #T_cfaf1_row4_col22, #T_cfaf1_row4_col23 {
#   background-color: #f5e9f2;
# }
# </style>
# <table id="T_cfaf1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfaf1_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_cfaf1_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_cfaf1_level0_col2" class="col_heading level0 col2" >self_employed</th>
#       <th id="T_cfaf1_level0_col3" class="col_heading level0 col3" >family_history</th>
#       <th id="T_cfaf1_level0_col4" class="col_heading level0 col4" >treatment</th>
#       <th id="T_cfaf1_level0_col5" class="col_heading level0 col5" >work_interfere</th>
#       <th id="T_cfaf1_level0_col6" class="col_heading level0 col6" >no_employees</th>
#       <th id="T_cfaf1_level0_col7" class="col_heading level0 col7" >remote_work</th>
#       <th id="T_cfaf1_level0_col8" class="col_heading level0 col8" >tech_company</th>
#       <th id="T_cfaf1_level0_col9" class="col_heading level0 col9" >benefits</th>
#       <th id="T_cfaf1_level0_col10" class="col_heading level0 col10" >care_options</th>
#       <th id="T_cfaf1_level0_col11" class="col_heading level0 col11" >wellness_program</th>
#       <th id="T_cfaf1_level0_col12" class="col_heading level0 col12" >seek_help</th>
#       <th id="T_cfaf1_level0_col13" class="col_heading level0 col13" >anonymity</th>
#       <th id="T_cfaf1_level0_col14" class="col_heading level0 col14" >leave</th>
#       <th id="T_cfaf1_level0_col15" class="col_heading level0 col15" >mental_health_consequence</th>
#       <th id="T_cfaf1_level0_col16" class="col_heading level0 col16" >phys_health_consequence</th>
#       <th id="T_cfaf1_level0_col17" class="col_heading level0 col17" >coworkers</th>
#       <th id="T_cfaf1_level0_col18" class="col_heading level0 col18" >supervisor</th>
#       <th id="T_cfaf1_level0_col19" class="col_heading level0 col19" >mental_health_interview</th>
#       <th id="T_cfaf1_level0_col20" class="col_heading level0 col20" >phys_health_interview</th>
#       <th id="T_cfaf1_level0_col21" class="col_heading level0 col21" >mental_vs_physical</th>
#       <th id="T_cfaf1_level0_col22" class="col_heading level0 col22" >obs_consequence</th>
#       <th id="T_cfaf1_level0_col23" class="col_heading level0 col23" >Age_cat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfaf1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cfaf1_row0_col0" class="data row0 col0" >Female</td>
#       <td id="T_cfaf1_row0_col1" class="data row0 col1" >North America</td>
#       <td id="T_cfaf1_row0_col2" class="data row0 col2" >No</td>
#       <td id="T_cfaf1_row0_col3" class="data row0 col3" >No</td>
#       <td id="T_cfaf1_row0_col4" class="data row0 col4" >Yes</td>
#       <td id="T_cfaf1_row0_col5" class="data row0 col5" >Often</td>
#       <td id="T_cfaf1_row0_col6" class="data row0 col6" >6-25</td>
#       <td id="T_cfaf1_row0_col7" class="data row0 col7" >No</td>
#       <td id="T_cfaf1_row0_col8" class="data row0 col8" >Yes</td>
#       <td id="T_cfaf1_row0_col9" class="data row0 col9" >Yes</td>
#       <td id="T_cfaf1_row0_col10" class="data row0 col10" >Not sure</td>
#       <td id="T_cfaf1_row0_col11" class="data row0 col11" >No</td>
#       <td id="T_cfaf1_row0_col12" class="data row0 col12" >Yes</td>
#       <td id="T_cfaf1_row0_col13" class="data row0 col13" >Yes</td>
#       <td id="T_cfaf1_row0_col14" class="data row0 col14" >Somewhat easy</td>
#       <td id="T_cfaf1_row0_col15" class="data row0 col15" >No</td>
#       <td id="T_cfaf1_row0_col16" class="data row0 col16" >No</td>
#       <td id="T_cfaf1_row0_col17" class="data row0 col17" >Some of them</td>
#       <td id="T_cfaf1_row0_col18" class="data row0 col18" >Yes</td>
#       <td id="T_cfaf1_row0_col19" class="data row0 col19" >No</td>
#       <td id="T_cfaf1_row0_col20" class="data row0 col20" >Maybe</td>
#       <td id="T_cfaf1_row0_col21" class="data row0 col21" >Yes</td>
#       <td id="T_cfaf1_row0_col22" class="data row0 col22" >No</td>
#       <td id="T_cfaf1_row0_col23" class="data row0 col23" >Adult</td>
#     </tr>
#     <tr>
#       <th id="T_cfaf1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cfaf1_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_cfaf1_row1_col1" class="data row1 col1" >North America</td>
#       <td id="T_cfaf1_row1_col2" class="data row1 col2" >No</td>
#       <td id="T_cfaf1_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_cfaf1_row1_col4" class="data row1 col4" >No</td>
#       <td id="T_cfaf1_row1_col5" class="data row1 col5" >Rarely</td>
#       <td id="T_cfaf1_row1_col6" class="data row1 col6" >More than 1000</td>
#       <td id="T_cfaf1_row1_col7" class="data row1 col7" >No</td>
#       <td id="T_cfaf1_row1_col8" class="data row1 col8" >No</td>
#       <td id="T_cfaf1_row1_col9" class="data row1 col9" >Don't know</td>
#       <td id="T_cfaf1_row1_col10" class="data row1 col10" >No</td>
#       <td id="T_cfaf1_row1_col11" class="data row1 col11" >Don't know</td>
#       <td id="T_cfaf1_row1_col12" class="data row1 col12" >Don't know</td>
#       <td id="T_cfaf1_row1_col13" class="data row1 col13" >Don't know</td>
#       <td id="T_cfaf1_row1_col14" class="data row1 col14" >Don't know</td>
#       <td id="T_cfaf1_row1_col15" class="data row1 col15" >Maybe</td>
#       <td id="T_cfaf1_row1_col16" class="data row1 col16" >No</td>
#       <td id="T_cfaf1_row1_col17" class="data row1 col17" >No</td>
#       <td id="T_cfaf1_row1_col18" class="data row1 col18" >No</td>
#       <td id="T_cfaf1_row1_col19" class="data row1 col19" >No</td>
#       <td id="T_cfaf

# %% [markdown]
# # Part 2

# %% [markdown]
# ![Screenshot%20%28399%29.png](attachment:Screenshot%20%28399%29.png)

# %%
#from sklearn import preprocessing
encoded_data=data.apply(LabelEncoder().fit_transform)
encoded_data.head().style.applymap(lambda x : "background-color: #f5e9f2")
# Out:
# <style type="text/css">
# #T_d090a_row0_col0, #T_d090a_row0_col1, #T_d090a_row0_col2, #T_d090a_row0_col3, #T_d090a_row0_col4, #T_d090a_row0_col5, #T_d090a_row0_col6, #T_d090a_row0_col7, #T_d090a_row0_col8, #T_d090a_row0_col9, #T_d090a_row0_col10, #T_d090a_row0_col11, #T_d090a_row0_col12, #T_d090a_row0_col13, #T_d090a_row0_col14, #T_d090a_row0_col15, #T_d090a_row0_col16, #T_d090a_row0_col17, #T_d090a_row0_col18, #T_d090a_row0_col19, #T_d090a_row0_col20, #T_d090a_row0_col21, #T_d090a_row0_col22, #T_d090a_row0_col23, #T_d090a_row1_col0, #T_d090a_row1_col1, #T_d090a_row1_col2, #T_d090a_row1_col3, #T_d090a_row1_col4, #T_d090a_row1_col5, #T_d090a_row1_col6, #T_d090a_row1_col7, #T_d090a_row1_col8, #T_d090a_row1_col9, #T_d090a_row1_col10, #T_d090a_row1_col11, #T_d090a_row1_col12, #T_d090a_row1_col13, #T_d090a_row1_col14, #T_d090a_row1_col15, #T_d090a_row1_col16, #T_d090a_row1_col17, #T_d090a_row1_col18, #T_d090a_row1_col19, #T_d090a_row1_col20, #T_d090a_row1_col21, #T_d090a_row1_col22, #T_d090a_row1_col23, #T_d090a_row2_col0, #T_d090a_row2_col1, #T_d090a_row2_col2, #T_d090a_row2_col3, #T_d090a_row2_col4, #T_d090a_row2_col5, #T_d090a_row2_col6, #T_d090a_row2_col7, #T_d090a_row2_col8, #T_d090a_row2_col9, #T_d090a_row2_col10, #T_d090a_row2_col11, #T_d090a_row2_col12, #T_d090a_row2_col13, #T_d090a_row2_col14, #T_d090a_row2_col15, #T_d090a_row2_col16, #T_d090a_row2_col17, #T_d090a_row2_col18, #T_d090a_row2_col19, #T_d090a_row2_col20, #T_d090a_row2_col21, #T_d090a_row2_col22, #T_d090a_row2_col23, #T_d090a_row3_col0, #T_d090a_row3_col1, #T_d090a_row3_col2, #T_d090a_row3_col3, #T_d090a_row3_col4, #T_d090a_row3_col5, #T_d090a_row3_col6, #T_d090a_row3_col7, #T_d090a_row3_col8, #T_d090a_row3_col9, #T_d090a_row3_col10, #T_d090a_row3_col11, #T_d090a_row3_col12, #T_d090a_row3_col13, #T_d090a_row3_col14, #T_d090a_row3_col15, #T_d090a_row3_col16, #T_d090a_row3_col17, #T_d090a_row3_col18, #T_d090a_row3_col19, #T_d090a_row3_col20, #T_d090a_row3_col21, #T_d090a_row3_col22, #T_d090a_row3_col23, #T_d090a_row4_col0, #T_d090a_row4_col1, #T_d090a_row4_col2, #T_d090a_row4_col3, #T_d090a_row4_col4, #T_d090a_row4_col5, #T_d090a_row4_col6, #T_d090a_row4_col7, #T_d090a_row4_col8, #T_d090a_row4_col9, #T_d090a_row4_col10, #T_d090a_row4_col11, #T_d090a_row4_col12, #T_d090a_row4_col13, #T_d090a_row4_col14, #T_d090a_row4_col15, #T_d090a_row4_col16, #T_d090a_row4_col17, #T_d090a_row4_col18, #T_d090a_row4_col19, #T_d090a_row4_col20, #T_d090a_row4_col21, #T_d090a_row4_col22, #T_d090a_row4_col23 {
#   background-color: #f5e9f2;
# }
# </style>
# <table id="T_d090a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d090a_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_d090a_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_d090a_level0_col2" class="col_heading level0 col2" >self_employed</th>
#       <th id="T_d090a_level0_col3" class="col_heading level0 col3" >family_history</th>
#       <th id="T_d090a_level0_col4" class="col_heading level0 col4" >treatment</th>
#       <th id="T_d090a_level0_col5" class="col_heading level0 col5" >work_interfere</th>
#       <th id="T_d090a_level0_col6" class="col_heading level0 col6" >no_employees</th>
#       <th id="T_d090a_level0_col7" class="col_heading level0 col7" >remote_work</th>
#       <th id="T_d090a_level0_col8" class="col_heading level0 col8" >tech_company</th>
#       <th id="T_d090a_level0_col9" class="col_heading level0 col9" >benefits</th>
#       <th id="T_d090a_level0_col10" class="col_heading level0 col10" >care_options</th>
#       <th id="T_d090a_level0_col11" class="col_heading level0 col11" >wellness_program</th>
#       <th id="T_d090a_level0_col12" class="col_heading level0 col12" >seek_help</th>
#       <th id="T_d090a_level0_col13" class="col_heading level0 col13" >anonymity</th>
#       <th id="T_d090a_level0_col14" class="col_heading level0 col14" >leave</th>
#       <th id="T_d090a_level0_col15" class="col_heading level0 col15" >mental_health_consequence</th>
#       <th id="T_d090a_level0_col16" class="col_heading level0 col16" >phys_health_consequence</th>
#       <th id="T_d090a_level0_col17" class="col_heading level0 col17" >coworkers</th>
#       <th id="T_d090a_level0_col18" class="col_heading level0 col18" >supervisor</th>
#       <th id="T_d090a_level0_col19" class="col_heading level0 col19" >mental_health_interview</th>
#       <th id="T_d090a_level0_col20" class="col_heading level0 col20" >phys_health_interview</th>
#       <th id="T_d090a_level0_col21" class="col_heading level0 col21" >mental_vs_physical</th>
#       <th id="T_d090a_level0_col22" class="col_heading level0 col22" >obs_consequence</th>
#       <th id="T_d090a_level0_col23" class="col_heading level0 col23" >Age_cat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d090a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d090a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d090a_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_d090a_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_d090a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d090a_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_d090a_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_d090a_row0_col6" class="data row0 col6" >4</td>
#       <td id="T_d090a_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_d090a_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_d090a_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_d090a_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_d090a_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_d090a_row0_col12" class="data row0 col12" >2</td>
#       <td id="T_d090a_row0_col13" class="data row0 col13" >2</td>
#       <td id="T_d090a_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_d090a_row0_col15" class="data row0 col15" >1</td>
#       <td id="T_d090a_row0_col16" class="data row0 col16" >1</td>
#       <td id="T_d090a_row0_col17" class="data row0 col17" >1</td>
#       <td id="T_d090a_row0_col18" class="data row0 col18" >2</td>
#       <td id="T_d090a_row0_col19" class="data row0 col19" >1</td>
#       <td id="T_d090a_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_d090a_row0_col21" class="data row0 col21" >2</td>
#       <td id="T_d090a_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_d090a_row0_col23" class="data row0 col23" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d090a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d090a_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_d090a_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_d090a_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_d090a_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_d090a_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_d090a_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_d090a_row1_col6" class="data row1 col6" >5</td>
#       <td id="T_d090a_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_d090a_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_d090a_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_d090a_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_d090a_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_d090a_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_d090a_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_d090a_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_d090a_row1_col15" class="data row1 col15" >0</td>
#       <td id="T_d090a_row1_col16" class="data row1 col16" >1</td>
#       <td id="T_d090a_row1_col17" class="data row1 col17" >0</td>
#       <td id="T_d090a_row1_col18" class="data row1 col18" >0</td>
#       <td id="T_d090a_row1_col19" class="data row1 col19" >1</td>
#       <td id="T_d090a_row1_col20" class="data row1 col20" >1</td>
#       <td id="T_d090a_row1_col21" class="data row1 col21" >0</td>
#       <td id="T_d090a_row1_col22" class="data row1 col22" >0</td

# %% [markdown]
# ### exploring target variable

# %%
df['self_employed'].value_counts()
# Out:
# 0    1110
# 1     149
# Name: self_employed, dtype: int64

# %%
df = encoded_data.copy()

X = df.drop(['self_employed'], axis=1)
y = df['self_employed']

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ![1_-8_kogvwmL1H6ooN1A1tsQ-2.png](attachment:1_-8_kogvwmL1H6ooN1A1tsQ-2.png)

# %% [markdown]
# ![Screenshot%20%28407%29.png](attachment:Screenshot%20%28407%29.png)

# %% [markdown]
# ## Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import recall_score
tree_params= param_dist={
   "criterion":['gini', 'entropy', 'log_loss'],
   "max_depth":[0,7,8,9,10,12,None],
    'splitter':['best', 'random'],
    #'max_features':[4,5,'auto', 'sqrt', 'log2'],
    'random_state':[4,5,6,7,8,9,None],
    #'max_leaf_nodes':[5,6,7,8,9,None]
}

tree_grid = GridSearchCV(DecisionTreeClassifier(), tree_params, scoring = 'accuracy',cv = 3)
tree_grid.fit(X_train, y_train)
tree_grid.best_estimator_
y_pred = tree_grid.predict(X_test)
best_score = tree_grid.best_score_
best_params = tree_grid.best_params_
precision = precision_score(y_test, y_pred)
roc = roc_auc_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)


print(f'Training set score: {round(tree_grid.score(X_train, y_train) * 100, 2)}%')
print ('--')
print ('Testing set Score is',best_score * 100)
print ('--')
print ('Best Parameters is', best_params)
print ('--')
print ('ROC Score is', roc)
print ('--')
print ('Recall Score is ', recall)
print ('--')
print ('Confusion Matrix\n\n', cm)
# Out:
# Training set score: 95.23%
# --
# Testing set Score is 90.5662165363658
# --
# Best Parameters is {'criterion': 'entropy', 'max_depth': 7, 'random_state': 5, 'splitter': 'random'}
# --
# ROC Score is 0.7166847237269773
# --
# Recall Score is  0.46153846153846156
# --
# Confusion Matrix
#
#  [[207   6]
#  [ 21  18]]

# %% [markdown]
# # Decision Tree Using Entropy

# %%
from sklearn.tree import DecisionTreeClassifier
# instantiate the DecisionTreeClassifier model with criterion entropy

clf_en = DecisionTreeClassifier(criterion='entropy', max_depth=7, random_state=4)

# fit the model
clf_en.fit(X_train, y_train)
 
y_pred_en = clf_en.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

y_pred_train_en = clf_en.predict(X_train)
print('accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_en)*100))
# Out:
# accuracy score: 95.4320

# %% [markdown]
# ![Screenshot%20%28402%29.png](attachment:Screenshot%20%28402%29.png)
# source : obviously.ai

# %% [markdown]
# ## Decision tree symbols

# %% [markdown]
# Alternative branches: Alternative branches are two lines that branch out from one decision on your decision tree. These branches show two outcomes or decisions that stem from the initial decision on your tree.
#
# Decision nodes: Decision nodes are squares and represent a decision being made on your tree. Every decision tree starts with a decision node.
#
# Chance nodes: Chance nodes are circles that show multiple possible outcomes.
#
# End nodes: End nodes are triangles that show a final outcome.

# %% [markdown]
# ## this code generated to us the decision tree before hyperparameter tuning but when we used it again with max_depth =7 it became so small and not clear so we left it as a comment and the tree before tuning will be inserted as a picutre in the report

# %%
'''from sklearn import tree
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf_en, 
                   feature_names=X_train.columns,  
                   class_names=str(y_train),
                   filled=True, rounded=True)

plt.savefig('tree.png', bbox_inches='tight',facecolor='white',dpi=1200) '''
print()

# %% [markdown]
# # Confusion matrix
#
# * True Positives (TP) – True Positives occur when we predict an observation belongs to a certain class and the observation actually belongs to that class.
#
# * True Negatives (TN) – True Negatives occur when we predict an observation does not belong to a certain class and the observation actually does not belong to that class.
#
# * False Positives (FP) – False Positives occur when we predict an observation belongs to a certain class but the observation actually does not belong to that class. This type of error is called Type I error.
#
# * False Negatives (FN) – False Negatives occur when we predict an observation does not belong to a certain class but the observation actually belongs to that class. This is a very serious error and it is called Type II error.

# %% [markdown]
# ![0f59a975b60e83f5309a5f59075e7f_jumbo.jpeg](attachment:0f59a975b60e83f5309a5f59075e7f_jumbo.jpeg)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_pred_en, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
plt.figure(dpi=100)
sns.heatmap(cm/np.sum(cm), annot=True, 
            fmt='.2%', cmap = 'tab20b')
plt.show()
# Out:
# Confusion Matrix :

# %% [markdown]
# # Classification Report

# %% [markdown]
# Precision - Precision is the ratio of correctly predicted positive observations to the total predicted positive observations. The question that this metric answer is of all passengers that labeled as survived, how many actually survived? High precision relates to the low false positive rate. We have got 0.788 precision which is pretty good.
#
# Precision = TP/TP+FP
#
# Recall (Sensitivity) - Recall is the ratio of correctly predicted positive observations to the all observations in actual class - yes. The question recall answers is: Of all the passengers that truly survived, how many did we label? A recall greater than 0.5 is good.
#
# Recall = TP/TP+FN

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_en))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       213
#            1       0.71      0.44      0.54        39
#
#     accuracy                           0.88       252
#    macro avg       0.81      0.70      0.74       252
# weighted avg       0.87      0.88      0.87       252

# %% [markdown]
# ![Screenshot%20%28406%29.png](attachment:Screenshot%20%28406%29.png)

# %% [markdown]
# # K-Nearest Neighbors (KNN)

# %% [markdown]
# K-nearest neighbors (KNN) algorithm is a type of supervised ML algorithm which can be used for both classification as well as regression predictive problems. However, it is mainly used for classification predictive problems in industry

# %% [markdown]
# ![1_RhMnNNBdNWYP_gEcUiNZKg.png](attachment:1_RhMnNNBdNWYP_gEcUiNZKg.png)

# %%
from sklearn.neighbors import KNeighborsClassifier


test_scores = []
train_scores = []

for i in range(1,15):

    knn = KNeighborsClassifier(i)
    knn.fit(X_train,y_train)
    
    train_scores.append(knn.score(X_train,y_train))
    test_scores.append(knn.score(X_test,y_test))
y_pred = knn.predict(X_test)

# %% [markdown]
# ## To classify an unknown record:
# * Initialize the K value.
# * Calculate the distance between test input and K trained nearest neighbors.
# * Check class categories of nearest neighbors and determine the type in which test input falls.
# * Classification will be done by taking the majority of votes.
# * Return the class category.

# %%
## score that comes from testing on the datapoints that were split in the beginning to be used for testing solely
max_test_score = max(test_scores)
test_scores_ind = [i for i, v in enumerate(test_scores) if v == max_test_score]
print('Max test score {} % and k = {}'.format(max_test_score*100,list(map(lambda x: x+1, test_scores_ind))))
# Out:
# Max test score 87.6984126984127 % and k = [5]

# %%
plt.figure(figsize=(12,5))
p = sns.lineplot(range(1,15),train_scores,marker='*',label='Train Score')
p = sns.lineplot(range(1,15),test_scores,marker='o',label='Test Score')

# %%
#Setup a knn classifier with k neighbors
knn = KNeighborsClassifier(5)

knn.fit(X_train,y_train)
knn.score(X_test,y_test)*100
# Out:
# 87.6984126984127

# %% [markdown]
# # KNN confusion matrix

# %%
cm = confusion_matrix(y_pred, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
plt.figure(dpi=100)
sns.heatmap(cm/np.sum(cm), annot=True, 
            fmt='.2%', cmap = 'tab20b')
plt.show()
# Out:
# Confusion Matrix :

# %% [markdown]
# # KNN classification report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93       213
#            1       1.00      0.13      0.23        39
#
#     accuracy                           0.87       252
#    macro avg       0.93      0.56      0.58       252
# weighted avg       0.88      0.87      0.82       252

# %%
# train a Gaussian Naive Bayes classifier on the training set
from sklearn.naive_bayes import GaussianNB


# instantiate the model
gnb = GaussianNB()


# fit the model
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)

# %%
print('Model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score: 0.8611

# %%
y_pred_train = gnb.predict(X_train)
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# Out:
# Training-set accuracy score: 0.8898

# %% [markdown]
# # Check for overfitting and underfitting

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(gnb.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(gnb.score(X_test, y_test)))
# Out:
# Training set score: 0.8898
# Test set score: 0.8611

# %% [markdown]
# # naive bayes confusion matrix

# %%
cm = confusion_matrix(y_pred, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
plt.figure(dpi=100)
sns.heatmap(cm/np.sum(cm), annot=True, 
            fmt='.2%', cmap = 'tab20b')
plt.show()
# Out:
# Confusion Matrix :

# %% [markdown]
#  # naive bayes classification report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       213
#            1       0.55      0.56      0.56        39
#
#     accuracy                           0.86       252
#    macro avg       0.73      0.74      0.74       252
# weighted avg       0.86      0.86      0.86       252
